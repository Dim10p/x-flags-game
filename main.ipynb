# %% [markdown]
# # X Flags
#
# **Author:** Dimitrios Petridis
#
# ---
#
# ## Introduction
#
# Welcome to the X Flags game simulation! In this game, two players take turns to pick flags, with a twist. Each player can pick from 1 up to a maximum number of flags during their turn. The player who picks the last flag is considered the winner. This Jupyter notebook provides a visual simulation of the game, highlighting the optimal strategy a player can adopt based on the given parameters of total flags and maximum flags allowed per turn.
#
# Find below some examples to visualize different game scenarios:

# %%
# Import the XFlags class:
from scripts import XFlags

# %%
game = XFlags(21, 3)
game_simulation = game.simulate_game()
game.visualize_moves(game_simulation)
# Out:
# X Flags - Total Flags: 21, Max Flags per Turn: 3
# ------------------------------------------------------------
# The optimal strategy is: ('first', 1)
# ------------------------------------------------------------
# first player picked 1 flags. Remaining flags: 20
# second player picked 1 flags. Remaining flags: 19
# first player picked 3 flags. Remaining flags: 16
# second player picked 2 flags. Remaining flags: 14
# first player picked 2 flags. Remaining flags: 12
# second player picked 3 flags. Remaining flags: 9
# first player picked 1 flags. Remaining flags: 8
# second player picked 3 flags. Remaining flags: 5
# first player picked 1 flags. Remaining flags: 4
# second player picked 3 flags. Remaining flags: 1
# first player picked 1 flags. Remaining flags: 0

# %%
game = XFlags(24, 3)
game_simulation = game.simulate_game()
game.visualize_moves(game_simulation)
# Out:
# X Flags - Total Flags: 24, Max Flags per Turn: 3
# ------------------------------------------------------------
# The optimal strategy is: ('second', None)
# ------------------------------------------------------------
# second player picked 1 flags. Remaining flags: 23
# first player picked 3 flags. Remaining flags: 20
# second player picked 3 flags. Remaining flags: 17
# first player picked 1 flags. Remaining flags: 16
# second player picked 2 flags. Remaining flags: 14
# first player picked 2 flags. Remaining flags: 12
# second player picked 1 flags. Remaining flags: 11
# first player picked 3 flags. Remaining flags: 8
# second player picked 1 flags. Remaining flags: 7
# first player picked 3 flags. Remaining flags: 4
# second player picked 1 flags. Remaining flags: 3
# first player picked 3 flags. Remaining flags: 0

# %%
game = XFlags(22, 5)
game_simulation = game.simulate_game()
game.visualize_moves(game_simulation)
# Out:
# X Flags - Total Flags: 22, Max Flags per Turn: 5
# ------------------------------------------------------------
# The optimal strategy is: ('first', 4)
# ------------------------------------------------------------
# first player picked 4 flags. Remaining flags: 18
# second player picked 5 flags. Remaining flags: 13
# first player picked 1 flags. Remaining flags: 12
# second player picked 2 flags. Remaining flags: 10
# first player picked 4 flags. Remaining flags: 6
# second player picked 4 flags. Remaining flags: 2
# first player picked 2 flags. Remaining flags: 0

# %%
game = XFlags(18, 5)
game_simulation = game.simulate_game()
game.visualize_moves(game_simulation)
# Out:
# X Flags - Total Flags: 18, Max Flags per Turn: 5
# ------------------------------------------------------------
# The optimal strategy is: ('second', None)
# ------------------------------------------------------------
# second player picked 1 flags. Remaining flags: 17
# first player picked 5 flags. Remaining flags: 12
# second player picked 4 flags. Remaining flags: 8
# first player picked 2 flags. Remaining flags: 6
# second player picked 4 flags. Remaining flags: 2
# first player picked 2 flags. Remaining flags: 0
